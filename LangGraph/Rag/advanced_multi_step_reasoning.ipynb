# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: aiohappyeyeballs==2.6.1 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 1)) (2.6.1)
# Collecting aiohttp==3.12.15 (from -r requirements.txt (line 2))
#   Downloading aiohttp-3.12.15-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.7 kB)
# Requirement already satisfied: aiosignal==1.4.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 3)) (1.4.0)
# Collecting aiosqlite==0.21.0 (from -r requirements.txt (line 4))
#   Downloading aiosqlite-0.21.0-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: annotated-types==0.7.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 5)) (0.7.0)
# Collecting anthropic==0.69.0 (from -r requirements.txt (line 6))
#   Downloading anthropic-0.69.0-py3-none-any.whl.metadata (28 kB)
# Requirement already satisfied: anyio==4.11.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 7)) (4.11.0)
# Collecting asttokens==3.0.0 (from -r requirements.txt (line 8))
#   Downloading asttokens-3.0.0-py3-none-any.whl.metadata (4.7 kB)
# Collecting attrs==25.3.0 (from -r requirements.txt (line 9))
#   Downloading attrs-25.3.0-py3-none-any.whl.metadata (10 kB)
# Collecting backoff==2.2.1 (from -r requirements.txt (line 10))
#   Downloading backoff-2.2.1-py3-none-any.whl.metadata (14 kB)
# Collecting bcrypt==5.0.0 (from -r requirements.txt (line 11))
#   Downloading bcrypt-5.0.0-cp39-abi3-manylinux_2_34_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: build==1.3.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 12)) (1.3.0)
# Collecting cachetools==6.2.0 (from -r requirements.txt (line 13))
#   Downloading cachetools-6.2.0-py3-none-any.whl.metadata (5.4 kB)
# Collecting certifi==2025.8.3 (from -r requirements.txt (line 14))
#   Downloading certifi-2025.8.3-py3-none-any.whl.metadata (2.4 kB)
# Collecting charset-normalizer==3.4.3 (from -r requirements.txt (line 15))
#   Downloading charset_normalizer-3.4.3-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (36 kB)
# Collecting chromadb==1.1.0 (from -r requirements.txt (line 16))
#   Downloading chromadb-1.1.0-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.2 kB)
# Requirement already satisfied: click==8.3.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 17)) (8.3.0)
# Collecting colorama==0.4.6 (from -r requirements.txt (line 18))
#   Downloading colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Collecting coloredlogs==15.0.1 (from -r requirements.txt (line 19))
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Collecting comm==0.2.3 (from -r requirements.txt (line 20))
#   Downloading comm-0.2.3-py3-none-any.whl.metadata (3.7 kB)
# Collecting dataclasses-json==0.6.7 (from -r requirements.txt (line 21))
#   Downloading dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Collecting debugpy==1.8.17 (from -r requirements.txt (line 22))
#   Downloading debugpy-1.8.17-cp312-cp312-manylinux_2_34_x86_64.whl.metadata (1.4 kB)
# Collecting decorator==5.2.1 (from -r requirements.txt (line 23))
#   Downloading decorator-5.2.1-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: distro==1.9.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 24)) (1.9.0)
# Requirement already satisfied: docstring_parser==0.17.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 25)) (0.17.0)
# Collecting durationpy==0.10 (from -r requirements.txt (line 26))
#   Downloading durationpy-0.10-py3-none-any.whl.metadata (340 bytes)
# Collecting executing==2.2.1 (from -r requirements.txt (line 27))
#   Downloading executing-2.2.1-py2.py3-none-any.whl.metadata (8.9 kB)
# Collecting filelock==3.19.1 (from -r requirements.txt (line 28))
#   Downloading filelock-3.19.1-py3-none-any.whl.metadata (2.1 kB)
# Requirement already satisfied: filetype==1.2.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 29)) (1.2.0)
# Requirement already satisfied: flatbuffers==25.9.23 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 30)) (25.9.23)
# Collecting frozenlist==1.7.0 (from -r requirements.txt (line 31))
#   Downloading frozenlist-1.7.0-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (18 kB)
# Collecting fsspec==2025.9.0 (from -r requirements.txt (line 32))
#   Downloading fsspec-2025.9.0-py3-none-any.whl.metadata (10 kB)
# Collecting functions==0.7.0 (from -r requirements.txt (line 33))
#   Downloading functions-0.7.0.tar.gz (2.7 kB)
#   Preparing metadata (setup.py) ... done
# Collecting google-ai-generativelanguage==0.7.0 (from -r requirements.txt (line 34))
#   Downloading google_ai_generativelanguage-0.7.0-py3-none-any.whl.metadata (10 kB)
# Collecting google-api-core==2.25.1 (from -r requirements.txt (line 35))
#   Downloading google_api_core-2.25.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting google-auth==2.41.1 (from -r requirements.txt (line 36))
#   Downloading google_auth-2.41.1-py2.py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: google-cloud-core==2.4.3 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 37)) (2.4.3)
# Requirement already satisfied: google-cloud-firestore==2.21.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 38)) (2.21.0)
# Requirement already satisfied: google-cloud-storage==2.19.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 39)) (2.19.0)
# Requirement already satisfied: google-crc32c==1.7.1 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 40)) (1.7.1)
# Collecting google-genai==1.39.1 (from -r requirements.txt (line 41))
#   Downloading google_genai-1.39.1-py3-none-any.whl.metadata (45 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.4/45.4 kB 4.1 MB/s eta 0:00:00
# Requirement already satisfied: google-resumable-media==2.7.2 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 42)) (2.7.2)
# Requirement already satisfied: googleapis-common-protos==1.70.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 43)) (1.70.0)
# Collecting grandalf==0.8 (from -r requirements.txt (line 44))
#   Downloading grandalf-0.8-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: greenlet==3.2.4 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 45)) (3.2.4)
# Collecting groq==0.32.0 (from -r requirements.txt (line 46))
#   Downloading groq-0.32.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: grpcio==1.75.1 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 47)) (1.75.1)
# Collecting grpcio-status==1.75.1 (from -r requirements.txt (line 48))
#   Downloading grpcio_status-1.75.1-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: h11==0.16.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 49)) (0.16.0)
# Requirement already satisfied: httpcore==1.0.9 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 50)) (1.0.9)
# Collecting httptools==0.6.4 (from -r requirements.txt (line 51))
#   Downloading httptools-0.6.4-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.6 kB)
# Requirement already satisfied: httpx==0.28.1 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 52)) (0.28.1)
# Collecting httpx-sse==0.4.1 (from -r requirements.txt (line 53))
#   Downloading httpx_sse-0.4.1-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: huggingface-hub==0.35.3 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 54)) (0.35.3)
# Collecting humanfriendly==10.0 (from -r requirements.txt (line 55))
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Collecting idna==3.10 (from -r requirements.txt (line 56))
#   Downloading idna-3.10-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: importlib_metadata==8.7.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 57)) (8.7.0)
# Requirement already satisfied: importlib_resources==6.5.2 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 58)) (6.5.2)
# Requirement already satisfied: iniconfig==2.1.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 59)) (2.1.0)
# Collecting ipykernel==7.0.1 (from -r requirements.txt (line 60))
#   Downloading ipykernel-7.0.1-py3-none-any.whl.metadata (4.5 kB)
# Collecting ipython==9.6.0 (from -r requirements.txt (line 61))
#   Downloading ipython-9.6.0-py3-none-any.whl.metadata (4.4 kB)
# Collecting ipython_pygments_lexers==1.1.1 (from -r requirements.txt (line 62))
#   Downloading ipython_pygments_lexers-1.1.1-py3-none-any.whl.metadata (1.1 kB)
# Collecting jedi==0.19.2 (from -r requirements.txt (line 63))
#   Downloading jedi-0.19.2-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: jiter==0.11.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 64)) (0.11.0)
# Requirement already satisfied: jsonpatch==1.33 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 65)) (1.33)
# Requirement already satisfied: jsonpointer==3.0.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 66)) (3.0.0)
# Requirement already satisfied: jsonschema==4.25.1 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 67)) (4.25.1)
# Requirement already satisfied: jsonschema-specifications==2025.9.1 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 68)) (2025.9.1)
# Collecting jupyter_client==8.6.3 (from -r requirements.txt (line 69))
#   Downloading jupyter_client-8.6.3-py3-none-any.whl.metadata (8.3 kB)
# Collecting jupyter_core==5.9.1 (from -r requirements.txt (line 70))
#   Downloading jupyter_core-5.9.1-py3-none-any.whl.metadata (1.5 kB)
# Collecting kubernetes==34.1.0 (from -r requirements.txt (line 71))
#   Downloading kubernetes-34.1.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: langchain==0.3.27 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 72)) (0.3.27)
# Collecting langchain-anthropic==0.3.21 (from -r requirements.txt (line 73))
#   Downloading langchain_anthropic-0.3.21-py3-none-any.whl.metadata (1.9 kB)
# Collecting langchain-chroma==0.2.6 (from -r requirements.txt (line 74))
#   Downloading langchain_chroma-0.2.6-py3-none-any.whl.metadata (1.1 kB)
# Collecting langchain-community==0.3.30 (from -r requirements.txt (line 75))
#   Downloading langchain_community-0.3.30-py3-none-any.whl.metadata (3.0 kB)
# Collecting langchain-core==0.3.77 (from -r requirements.txt (line 76))
#   Downloading langchain_core-0.3.77-py3-none-any.whl.metadata (3.2 kB)
# Collecting langchain-google-firestore==0.5.0 (from -r requirements.txt (line 77))
#   Downloading langchain_google_firestore-0.5.0-py3-none-any.whl.metadata (19 kB)
# Collecting langchain-google-genai==2.1.12 (from -r requirements.txt (line 78))
#   Downloading langchain_google_genai-2.1.12-py3-none-any.whl.metadata (7.1 kB)
# Collecting langchain-groq==0.3.8 (from -r requirements.txt (line 79))
#   Downloading langchain_groq-0.3.8-py3-none-any.whl.metadata (2.6 kB)
# Collecting langchain-openai==0.3.34 (from -r requirements.txt (line 80))
#   Downloading langchain_openai-0.3.34-py3-none-any.whl.metadata (2.4 kB)
# Collecting langchain-tavily==0.2.12 (from -r requirements.txt (line 81))
#   Downloading langchain_tavily-0.2.12-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: langchain-text-splitters==0.3.11 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 82)) (0.3.11)
# Collecting langgraph==0.6.10 (from -r requirements.txt (line 83))
#   Downloading langgraph-0.6.10-py3-none-any.whl.metadata (6.8 kB)
# Collecting langgraph-checkpoint==2.1.1 (from -r requirements.txt (line 84))
#   Downloading langgraph_checkpoint-2.1.1-py3-none-any.whl.metadata (4.2 kB)
# Collecting langgraph-checkpoint-sqlite==2.0.11 (from -r requirements.txt (line 85))
#   Downloading langgraph_checkpoint_sqlite-2.0.11-py3-none-any.whl.metadata (2.6 kB)
# Collecting langgraph-prebuilt==0.6.4 (from -r requirements.txt (line 86))
#   Downloading langgraph_prebuilt-0.6.4-py3-none-any.whl.metadata (4.5 kB)
# Collecting langgraph-sdk==0.2.9 (from -r requirements.txt (line 87))
#   Downloading langgraph_sdk-0.2.9-py3-none-any.whl.metadata (1.5 kB)
# Collecting langsmith==0.4.31 (from -r requirements.txt (line 88))
#   Downloading langsmith-0.4.31-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: markdown-it-py==4.0.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 89)) (4.0.0)
# Collecting marshmallow==3.26.1 (from -r requirements.txt (line 90))
#   Downloading marshmallow-3.26.1-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: matplotlib-inline==0.1.7 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 91)) (0.1.7)
# Requirement already satisfied: mdurl==0.1.2 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 92)) (0.1.2)
# Collecting mmh3==5.2.0 (from -r requirements.txt (line 93))
#   Downloading mmh3-5.2.0-cp312-cp312-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl.metadata (14 kB)
# Requirement already satisfied: more-itertools==10.8.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 94)) (10.8.0)
# Requirement already satisfied: mpmath==1.3.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 95)) (1.3.0)
# Collecting multidict==6.6.4 (from -r requirements.txt (line 96))
#   Downloading multidict-6.6.4-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (5.3 kB)
# Collecting mypy_extensions==1.1.0 (from -r requirements.txt (line 97))
#   Downloading mypy_extensions-1.1.0-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: nest-asyncio==1.6.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 98)) (1.6.0)
# Collecting numpy==2.3.3 (from -r requirements.txt (line 99))
#   Downloading numpy-2.3.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.1/62.1 kB 6.0 MB/s eta 0:00:00
# Requirement already satisfied: oauthlib==3.3.1 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 100)) (3.3.1)
# Collecting onnxruntime==1.23.0 (from -r requirements.txt (line 101))
#   Downloading onnxruntime-1.23.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (4.9 kB)
# Collecting openai==2.0.1 (from -r requirements.txt (line 102))
#   Downloading openai-2.0.1-py3-none-any.whl.metadata (29 kB)
# Requirement already satisfied: opentelemetry-api==1.37.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 103)) (1.37.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.37.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 104)) (1.37.0)
# Collecting opentelemetry-exporter-otlp-proto-grpc==1.37.0 (from -r requirements.txt (line 105))
#   Downloading opentelemetry_exporter_otlp_proto_grpc-1.37.0-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: opentelemetry-proto==1.37.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 106)) (1.37.0)
# Requirement already satisfied: opentelemetry-sdk==1.37.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 107)) (1.37.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.58b0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 108)) (0.58b0)
# Requirement already satisfied: orjson==3.11.3 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 109)) (3.11.3)
# Collecting ormsgpack==1.10.0 (from -r requirements.txt (line 110))
#   Downloading ormsgpack-1.10.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.7/43.7 kB 3.6 MB/s eta 0:00:00
# Requirement already satisfied: overrides==7.7.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 111)) (7.7.0)
# Requirement already satisfied: packaging==25.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 112)) (25.0)
# Requirement already satisfied: parso==0.8.5 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 113)) (0.8.5)
# Requirement already satisfied: platformdirs==4.5.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 114)) (4.5.0)
# Requirement already satisfied: pluggy==1.6.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 115)) (1.6.0)
# Collecting posthog==5.4.0 (from -r requirements.txt (line 116))
#   Downloading posthog-5.4.0-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: prompt_toolkit==3.0.52 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 117)) (3.0.52)
# Collecting propcache==0.3.2 (from -r requirements.txt (line 118))
#   Downloading propcache-0.3.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Requirement already satisfied: proto-plus==1.26.1 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 119)) (1.26.1)
# Collecting protobuf==6.32.1 (from -r requirements.txt (line 120))
#   Downloading protobuf-6.32.1-cp39-abi3-manylinux2014_x86_64.whl.metadata (593 bytes)
# Collecting psutil==7.1.0 (from -r requirements.txt (line 121))
#   Downloading psutil-7.1.0-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (23 kB)
# Collecting pure_eval==0.2.3 (from -r requirements.txt (line 122))
#   Downloading pure_eval-0.2.3-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: pyasn1==0.6.1 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 123)) (0.6.1)
# Requirement already satisfied: pyasn1_modules==0.4.2 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 124)) (0.4.2)
# Collecting pybase64==1.4.2 (from -r requirements.txt (line 125))
#   Downloading pybase64-1.4.2-cp312-cp312-manylinux1_x86_64.manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_5_x86_64.whl.metadata (8.7 kB)
# Collecting pydantic==2.11.9 (from -r requirements.txt (line 126))
#   Downloading pydantic-2.11.9-py3-none-any.whl.metadata (68 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.4/68.4 kB 4.8 MB/s eta 0:00:00
# Requirement already satisfied: pydantic-settings==2.11.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 127)) (2.11.0)
# Requirement already satisfied: pydantic_core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 128)) (2.33.2)
# Requirement already satisfied: Pygments==2.19.2 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 129)) (2.19.2)
# Requirement already satisfied: pyparsing==3.2.5 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 130)) (3.2.5)
# Collecting PyPika==0.48.9 (from -r requirements.txt (line 131))
#   Downloading PyPika-0.48.9.tar.gz (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 5.8 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: pyproject_hooks==1.2.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 132)) (1.2.0)
# Collecting pyreadline3==3.5.4 (from -r requirements.txt (line 133))
#   Downloading pyreadline3-3.5.4-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: pytest==8.4.2 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 134)) (8.4.2)
# Requirement already satisfied: python-dateutil==2.9.0.post0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 135)) (2.9.0.post0)
# Requirement already satisfied: python-dotenv==1.1.1 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 136)) (1.1.1)
# Requirement already satisfied: PyYAML==6.0.3 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 137)) (6.0.3)
# Collecting pyzmq==27.1.0 (from -r requirements.txt (line 138))
#   Downloading pyzmq-27.1.0-cp312-abi3-manylinux_2_26_x86_64.manylinux_2_28_x86_64.whl.metadata (6.0 kB)
# Collecting referencing==0.36.2 (from -r requirements.txt (line 139))
#   Downloading referencing-0.36.2-py3-none-any.whl.metadata (2.8 kB)
# Collecting regex==2025.9.18 (from -r requirements.txt (line 140))
#   Downloading regex-2025.9.18-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.5/40.5 kB 3.6 MB/s eta 0:00:00
# Collecting requests==2.32.5 (from -r requirements.txt (line 141))
#   Downloading requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: requests-oauthlib==2.0.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 142)) (2.0.0)
# Requirement already satisfied: requests-toolbelt==1.0.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 143)) (1.0.0)
# Collecting rich==14.1.0 (from -r requirements.txt (line 144))
#   Downloading rich-14.1.0-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: rpds-py==0.27.1 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 145)) (0.27.1)
# Requirement already satisfied: rsa==4.9.1 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 146)) (4.9.1)
# Collecting schemas==0.7.1 (from -r requirements.txt (line 147))
#   Downloading schemas-0.7.1.tar.gz (2.4 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: shellingham==1.5.4 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 148)) (1.5.4)
# Requirement already satisfied: six==1.17.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 149)) (1.17.0)
# Requirement already satisfied: sniffio==1.3.1 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 150)) (1.3.1)
# Collecting SQLAlchemy==2.0.43 (from -r requirements.txt (line 151))
#   Downloading sqlalchemy-2.0.43-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.6 kB)
# Collecting sqlite-vec==0.1.6 (from -r requirements.txt (line 152))
#   Downloading sqlite_vec-0.1.6-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux1_x86_64.whl.metadata (198 bytes)
# Collecting stack-data==0.6.3 (from -r requirements.txt (line 153))
#   Downloading stack_data-0.6.3-py3-none-any.whl.metadata (18 kB)
# Collecting sympy==1.14.0 (from -r requirements.txt (line 154))
#   Downloading sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Collecting tenacity==9.1.2 (from -r requirements.txt (line 155))
#   Downloading tenacity-9.1.2-py3-none-any.whl.metadata (1.2 kB)
# Collecting tiktoken==0.11.0 (from -r requirements.txt (line 156))
#   Downloading tiktoken-0.11.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: tokenizers==0.22.1 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 157)) (0.22.1)
# Collecting tornado==6.5.2 (from -r requirements.txt (line 158))
#   Downloading tornado-6.5.2-cp39-abi3-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.8 kB)
# Requirement already satisfied: tqdm==4.67.1 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 159)) (4.67.1)
# Collecting traitlets==5.14.3 (from -r requirements.txt (line 160))
#   Downloading traitlets-5.14.3-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: typer==0.19.2 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 161)) (0.19.2)
# Collecting typing-inspect==0.9.0 (from -r requirements.txt (line 162))
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: typing-inspection==0.4.2 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 163)) (0.4.2)
# Requirement already satisfied: typing_extensions==4.15.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 164)) (4.15.0)
# Collecting urllib3==2.3.0 (from -r requirements.txt (line 165))
#   Downloading urllib3-2.3.0-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: uvicorn==0.37.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 166)) (0.37.0)
# Collecting watchfiles==1.1.0 (from -r requirements.txt (line 167))
#   Downloading watchfiles-1.1.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Requirement already satisfied: wcwidth==0.2.14 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 168)) (0.2.14)
# Collecting websocket-client==1.8.0 (from -r requirements.txt (line 169))
#   Downloading websocket_client-1.8.0-py3-none-any.whl.metadata (8.0 kB)
# Requirement already satisfied: websockets==15.0.1 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 170)) (15.0.1)
# Requirement already satisfied: xxhash==3.6.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 171)) (3.6.0)
# Collecting yarl==1.20.1 (from -r requirements.txt (line 172))
#   Downloading yarl-1.20.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (73 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.9/73.9 kB 7.4 MB/s eta 0:00:00
# Requirement already satisfied: zipp==3.23.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 173)) (3.23.0)
# Requirement already satisfied: zstandard==0.25.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 174)) (0.25.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub==0.35.3->-r requirements.txt (line 54)) (1.1.10)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.12/dist-packages (from ipython==9.6.0->-r requirements.txt (line 61)) (4.9.0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.12/dist-packages (from pexpect>4.3->ipython==9.6.0->-r requirements.txt (line 61)) (0.7.0)
# Collecting uvloop>=0.15.1 (from uvicorn[standard]>=0.18.3->chromadb==1.1.0->-r requirements.txt (line 16))
#   Downloading uvloop-0.22.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (4.9 kB)
# Downloading aiohttp-3.12.15-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 73.6 MB/s eta 0:00:00
# Downloading aiosqlite-0.21.0-py3-none-any.whl (15 kB)
# Downloading anthropic-0.69.0-py3-none-any.whl (337 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 337.3/337.3 kB 29.4 MB/s eta 0:00:00
# Downloading asttokens-3.0.0-py3-none-any.whl (26 kB)
# Downloading attrs-25.3.0-py3-none-any.whl (63 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.8/63.8 kB 6.6 MB/s eta 0:00:00
# Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Downloading bcrypt-5.0.0-cp39-abi3-manylinux_2_34_x86_64.whl (278 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.2/278.2 kB 34.0 MB/s eta 0:00:00
# Downloading cachetools-6.2.0-py3-none-any.whl (11 kB)
# Downloading certifi-2025.8.3-py3-none-any.whl (161 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 161.2/161.2 kB 13.2 MB/s eta 0:00:00
# Downloading charset_normalizer-3.4.3-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (151 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 151.8/151.8 kB 14.8 MB/s eta 0:00:00
# Downloading chromadb-1.1.0-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (19.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.8/19.8 MB 57.9 MB/s eta 0:00:00
# Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 4.8 MB/s eta 0:00:00
# Downloading comm-0.2.3-py3-none-any.whl (7.3 kB)
# Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Downloading debugpy-1.8.17-cp312-cp312-manylinux_2_34_x86_64.whl (4.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 113.4 MB/s eta 0:00:00
# Downloading decorator-5.2.1-py3-none-any.whl (9.2 kB)
# Downloading durationpy-0.10-py3-none-any.whl (3.9 kB)
# Downloading executing-2.2.1-py2.py3-none-any.whl (28 kB)
# Downloading filelock-3.19.1-py3-none-any.whl (15 kB)
# Downloading frozenlist-1.7.0-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (241 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 241.8/241.8 kB 24.7 MB/s eta 0:00:00
# Downloading fsspec-2025.9.0-py3-none-any.whl (199 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.3/199.3 kB 13.9 MB/s eta 0:00:00
# Downloading google_ai_generativelanguage-0.7.0-py3-none-any.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 81.9 MB/s eta 0:00:00
# Downloading google_api_core-2.25.1-py3-none-any.whl (160 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 160.8/160.8 kB 10.8 MB/s eta 0:00:00
# Downloading google_auth-2.41.1-py2.py3-none-any.whl (221 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 221.3/221.3 kB 20.9 MB/s eta 0:00:00
# Downloading google_genai-1.39.1-py3-none-any.whl (244 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.7/244.7 kB 24.0 MB/s eta 0:00:00
# Downloading grandalf-0.8-py3-none-any.whl (41 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.8/41.8 kB 4.3 MB/s eta 0:00:00
# Downloading groq-0.32.0-py3-none-any.whl (135 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.4/135.4 kB 12.4 MB/s eta 0:00:00
# Downloading grpcio_status-1.75.1-py3-none-any.whl (14 kB)
# Downloading httptools-0.6.4-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (510 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 510.8/510.8 kB 37.8 MB/s eta 0:00:00
# Downloading httpx_sse-0.4.1-py3-none-any.whl (8.1 kB)
# Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 7.9 MB/s eta 0:00:00
# Downloading idna-3.10-py3-none-any.whl (70 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.4/70.4 kB 6.6 MB/s eta 0:00:00
# Downloading ipykernel-7.0.1-py3-none-any.whl (118 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.2/118.2 kB 14.9 MB/s eta 0:00:00
# Downloading ipython-9.6.0-py3-none-any.whl (616 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 616.2/616.2 kB 16.1 MB/s eta 0:00:00
# Downloading ipython_pygments_lexers-1.1.1-py3-none-any.whl (8.1 kB)
# Downloading jedi-0.19.2-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 79.5 MB/s eta 0:00:00
# Downloading jupyter_client-8.6.3-py3-none-any.whl (106 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.1/106.1 kB 8.3 MB/s eta 0:00:00
# Downloading jupyter_core-5.9.1-py3-none-any.whl (29 kB)
# Downloading kubernetes-34.1.0-py2.py3-none-any.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 95.9 MB/s eta 0:00:00
# Downloading langchain_anthropic-0.3.21-py3-none-any.whl (32 kB)
# Downloading langchain_chroma-0.2.6-py3-none-any.whl (12 kB)
# Downloading langchain_community-0.3.30-py3-none-any.whl (2.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 100.8 MB/s eta 0:00:00
# Downloading langchain_core-0.3.77-py3-none-any.whl (449 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 449.5/449.5 kB 40.3 MB/s eta 0:00:00
# Downloading langchain_google_firestore-0.5.0-py3-none-any.whl (23 kB)
# Downloading langchain_google_genai-2.1.12-py3-none-any.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.7/50.7 kB 5.3 MB/s eta 0:00:00
# Downloading langchain_groq-0.3.8-py3-none-any.whl (16 kB)
# Downloading langchain_openai-0.3.34-py3-none-any.whl (75 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 6.4 MB/s eta 0:00:00
# Downloading langchain_tavily-0.2.12-py3-none-any.whl (25 kB)
# Downloading langgraph-0.6.10-py3-none-any.whl (155 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.4/155.4 kB 12.9 MB/s eta 0:00:00
# Downloading langgraph_checkpoint-2.1.1-py3-none-any.whl (43 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.9/43.9 kB 3.8 MB/s eta 0:00:00
# Downloading langgraph_checkpoint_sqlite-2.0.11-py3-none-any.whl (31 kB)
# Downloading langgraph_prebuilt-0.6.4-py3-none-any.whl (28 kB)
# Downloading langgraph_sdk-0.2.9-py3-none-any.whl (56 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.8/56.8 kB 5.7 MB/s eta 0:00:00
# Downloading langsmith-0.4.31-py3-none-any.whl (386 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 386.3/386.3 kB 35.9 MB/s eta 0:00:00
# Downloading marshmallow-3.26.1-py3-none-any.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 5.1 MB/s eta 0:00:00
# Downloading mmh3-5.2.0-cp312-cp312-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl (103 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.3/103.3 kB 10.8 MB/s eta 0:00:00
# Downloading multidict-6.6.4-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (256 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 256.1/256.1 kB 23.7 MB/s eta 0:00:00
# Downloading mypy_extensions-1.1.0-py3-none-any.whl (5.0 kB)
# Downloading numpy-2.3.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.6/16.6 MB 123.7 MB/s eta 0:00:00
# Downloading onnxruntime-1.23.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (17.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 4.5 MB/s eta 0:00:00
# Downloading openai-2.0.1-py3-none-any.whl (956 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 956.3/956.3 kB 65.6 MB/s eta 0:00:00
# Downloading opentelemetry_exporter_otlp_proto_grpc-1.37.0-py3-none-any.whl (19 kB)
# Downloading ormsgpack-1.10.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (216 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 216.7/216.7 kB 20.9 MB/s eta 0:00:00
# Downloading posthog-5.4.0-py3-none-any.whl (105 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.4/105.4 kB 10.1 MB/s eta 0:00:00
# Downloading propcache-0.3.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (224 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.4/224.4 kB 21.9 MB/s eta 0:00:00
# Downloading protobuf-6.32.1-cp39-abi3-manylinux2014_x86_64.whl (322 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 322.0/322.0 kB 31.2 MB/s eta 0:00:00
# Downloading psutil-7.1.0-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (291 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 291.2/291.2 kB 29.8 MB/s eta 0:00:00
# Downloading pure_eval-0.2.3-py3-none-any.whl (11 kB)
# Downloading pybase64-1.4.2-cp312-cp312-manylinux1_x86_64.manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_5_x86_64.whl (71 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.6/71.6 kB 7.7 MB/s eta 0:00:00
# Downloading pydantic-2.11.9-py3-none-any.whl (444 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 444.9/444.9 kB 42.7 MB/s eta 0:00:00
# Downloading pyreadline3-3.5.4-py3-none-any.whl (83 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.2/83.2 kB 8.3 MB/s eta 0:00:00
# Downloading pyzmq-27.1.0-cp312-abi3-manylinux_2_26_x86_64.manylinux_2_28_x86_64.whl (840 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 841.0/841.0 kB 46.4 MB/s eta 0:00:00
# Downloading referencing-0.36.2-py3-none-any.whl (26 kB)
# Downloading regex-2025.9.18-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (802 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 802.0/802.0 kB 62.9 MB/s eta 0:00:00
# Downloading requests-2.32.5-py3-none-any.whl (64 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.7/64.7 kB 6.9 MB/s eta 0:00:00
# Downloading rich-14.1.0-py3-none-any.whl (243 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 243.4/243.4 kB 20.0 MB/s eta 0:00:00
# Downloading sqlalchemy-2.0.43-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 78.6 MB/s eta 0:00:00
# Downloading sqlite_vec-0.1.6-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux1_x86_64.whl (151 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 151.6/151.6 kB 11.4 MB/s eta 0:00:00
# Downloading stack_data-0.6.3-py3-none-any.whl (24 kB)
# Downloading sympy-1.14.0-py3-none-any.whl (6.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 148.6 MB/s eta 0:00:00
# Downloading tenacity-9.1.2-py3-none-any.whl (28 kB)
# Downloading tiktoken-0.11.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 68.1 MB/s eta 0:00:00
# Downloading tornado-6.5.2-cp39-abi3-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (443 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 443.9/443.9 kB 32.5 MB/s eta 0:00:00
# Downloading traitlets-5.14.3-py3-none-any.whl (85 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.4/85.4 kB 9.3 MB/s eta 0:00:00
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading urllib3-2.3.0-py3-none-any.whl (128 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.4/128.4 kB 13.0 MB/s eta 0:00:00
# Downloading watchfiles-1.1.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (452 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 452.2/452.2 kB 33.3 MB/s eta 0:00:00
# Downloading websocket_client-1.8.0-py3-none-any.whl (58 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 6.2 MB/s eta 0:00:00
# Downloading yarl-1.20.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (355 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 355.6/355.6 kB 35.7 MB/s eta 0:00:00
# Downloading uvloop-0.22.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (4.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 94.5 MB/s eta 0:00:00
# Building wheels for collected packages: functions, PyPika, schemas
#   Building wheel for functions (setup.py) ... done
#   Created wheel for functions: filename=functions-0.7.0-py3-none-any.whl size=3034 sha256=ef5cbcfdbf34f741539d195182b4ba5820410938a6e8d6e8c91bd5279fb5029e
#   Stored in directory: /root/.cache/pip/wheels/a1/4e/51/aa034b5bb6126b7a9a39c080c6656a3bd6388d3b8d8883bf66
#   Building wheel for PyPika (pyproject.toml) ... done
#   Created wheel for PyPika: filename=pypika-0.48.9-py2.py3-none-any.whl size=53803 sha256=2c984bccf47466c37218528320b2b66aad9995b750175835c17ae40a4c0d0204
#   Stored in directory: /root/.cache/pip/wheels/d5/3d/69/8d68d249cd3de2584f226e27fd431d6344f7d70fd856ebd01b
#   Building wheel for schemas (setup.py) ... done
#   Created wheel for schemas: filename=schemas-0.7.1-py3-none-any.whl size=2752 sha256=ae1554d08b826c236c60a270c6524babde22889c441a54db8f7904d798459fa9
#   Stored in directory: /root/.cache/pip/wheels/f1/df/21/448fe90ff7f2318b60f18470c9f16f4e4bc4cfb6e46600c920
# Successfully built functions PyPika schemas
# Installing collected packages: sqlite-vec, PyPika, pure_eval, functions, durationpy, websocket-client, uvloop, urllib3, traitlets, tornado, tenacity, sympy, SQLAlchemy, regex, pyzmq, pyreadline3, pybase64, psutil, protobuf, propcache, ormsgpack, numpy, mypy_extensions, multidict, mmh3, marshmallow, jedi, ipython_pygments_lexers, idna, humanfriendly, httpx-sse, httptools, grandalf, fsspec, frozenlist, filelock, executing, decorator, debugpy, comm, colorama, charset-normalizer, certifi, cachetools, bcrypt, backoff, attrs, asttokens, aiosqlite, yarl, typing-inspect, stack-data, schemas, rich, requests, referencing, pydantic, jupyter_core, google-auth, coloredlogs, watchfiles, tiktoken, posthog, onnxruntime, jupyter_client, ipython, grpcio-status, google-api-core, dataclasses-json, aiohttp, openai, langsmith, langgraph-sdk, kubernetes, ipykernel, groq, google-genai, anthropic, opentelemetry-exporter-otlp-proto-grpc, langchain-core, google-ai-generativelanguage, langgraph-checkpoint, langchain-openai, langchain-groq, langchain-google-genai, langchain-anthropic, chromadb, langgraph-prebuilt, langgraph-checkpoint-sqlite, langchain-chroma, langgraph, langchain-tavily, langchain-community, langchain-google-firestore
#   Attempting uninstall: websocket-client
#     Found existing installation: websocket-client 1.9.0
#     Uninstalling websocket-client-1.9.0:
#       Successfully uninstalled websocket-client-1.9.0
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.5.0
#     Uninstalling urllib3-2.5.0:
#       Successfully uninstalled urllib3-2.5.0
#   Attempting uninstall: traitlets
#     Found existing installation: traitlets 5.7.1
#     Uninstalling traitlets-5.7.1:
#       Successfully uninstalled traitlets-5.7.1
#   Attempting uninstall: tornado
#     Found existing installation: tornado 6.5.1
#     Uninstalling tornado-6.5.1:
#       Successfully uninstalled tornado-6.5.1
#   Attempting uninstall: tenacity
#     Found existing installation: tenacity 8.5.0
#     Uninstalling tenacity-8.5.0:
#       Successfully uninstalled tenacity-8.5.0
#   Attempting uninstall: sympy
#     Found existing installation: sympy 1.13.3
#     Uninstalling sympy-1.13.3:
#       Successfully uninstalled sympy-1.13.3
#   Attempting uninstall: SQLAlchemy
#     Found existing installation: SQLAlchemy 2.0.44
#     Uninstalling SQLAlchemy-2.0.44:
#       Successfully uninstalled SQLAlchemy-2.0.44
#   Attempting uninstall: regex
#     Found existing installation: regex 2024.11.6
#     Uninstalling regex-2024.11.6:
#       Successfully uninstalled regex-2024.11.6
#   Attempting uninstall: pyzmq
#     Found existing installation: pyzmq 26.2.1
#     Uninstalling pyzmq-26.2.1:
#       Successfully uninstalled pyzmq-26.2.1
#   Attempting uninstall: psutil
#     Found existing installation: psutil 5.9.5
#     Uninstalling psutil-5.9.5:
#       Successfully uninstalled psutil-5.9.5
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 5.29.5
#     Uninstalling protobuf-5.29.5:
#       Successfully uninstalled protobuf-5.29.5
#   Attempting uninstall: propcache
#     Found existing installation: propcache 0.4.1
#     Uninstalling propcache-0.4.1:
#       Successfully uninstalled propcache-0.4.1
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
#   Attempting uninstall: multidict
#     Found existing installation: multidict 6.7.0
#     Uninstalling multidict-6.7.0:
#       Successfully uninstalled multidict-6.7.0
#   Attempting uninstall: idna
#     Found existing installation: idna 3.11
#     Uninstalling idna-3.11:
#       Successfully uninstalled idna-3.11
#   Attempting uninstall: httpx-sse
#     Found existing installation: httpx-sse 0.4.3
#     Uninstalling httpx-sse-0.4.3:
#       Successfully uninstalled httpx-sse-0.4.3
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2025.3.0
#     Uninstalling fsspec-2025.3.0:
#       Successfully uninstalled fsspec-2025.3.0
#   Attempting uninstall: frozenlist
#     Found existing installation: frozenlist 1.8.0
#     Uninstalling frozenlist-1.8.0:
#       Successfully uninstalled frozenlist-1.8.0
#   Attempting uninstall: filelock
#     Found existing installation: filelock 3.20.0
#     Uninstalling filelock-3.20.0:
#       Successfully uninstalled filelock-3.20.0
#   Attempting uninstall: decorator
#     Found existing installation: decorator 4.4.2
#     Uninstalling decorator-4.4.2:
#       Successfully uninstalled decorator-4.4.2
#   Attempting uninstall: debugpy
#     Found existing installation: debugpy 1.8.15
#     Uninstalling debugpy-1.8.15:
#       Successfully uninstalled debugpy-1.8.15
#   Attempting uninstall: charset-normalizer
#     Found existing installation: charset-normalizer 3.4.4
#     Uninstalling charset-normalizer-3.4.4:
#       Successfully uninstalled charset-normalizer-3.4.4
#   Attempting uninstall: certifi
#     Found existing installation: certifi 2025.10.5
#     Uninstalling certifi-2025.10.5:
#       Successfully uninstalled certifi-2025.10.5
#   Attempting uninstall: cachetools
#     Found existing installation: cachetools 5.5.2
#     Uninstalling cachetools-5.5.2:
#       Successfully uninstalled cachetools-5.5.2
#   Attempting uninstall: attrs
#     Found existing installation: attrs 25.4.0
#     Uninstalling attrs-25.4.0:
#       Successfully uninstalled attrs-25.4.0
#   Attempting uninstall: yarl
#     Found existing installation: yarl 1.22.0
#     Uninstalling yarl-1.22.0:
#       Successfully uninstalled yarl-1.22.0
#   Attempting uninstall: rich
#     Found existing installation: rich 13.9.4
#     Uninstalling rich-13.9.4:
#       Successfully uninstalled rich-13.9.4
#   Attempting uninstall: requests
#     Found existing installation: requests 2.32.4
#     Uninstalling requests-2.32.4:
#       Successfully uninstalled requests-2.32.4
#   Attempting uninstall: referencing
#     Found existing installation: referencing 0.37.0
#     Uninstalling referencing-0.37.0:
#       Successfully uninstalled referencing-0.37.0
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 2.11.10
#     Uninstalling pydantic-2.11.10:
#       Successfully uninstalled pydantic-2.11.10
#   Attempting uninstall: jupyter_core
#     Found existing installation: jupyter_core 5.8.1
#     Uninstalling jupyter_core-5.8.1:
#       Successfully uninstalled jupyter_core-5.8.1
#   Attempting uninstall: google-auth
#     Found existing installation: google-auth 2.38.0
#     Uninstalling google-auth-2.38.0:
#       Successfully uninstalled google-auth-2.38.0
#   Attempting uninstall: tiktoken
#     Found existing installation: tiktoken 0.12.0
#     Uninstalling tiktoken-0.12.0:
#       Successfully uninstalled tiktoken-0.12.0
#   Attempting uninstall: jupyter_client
#     Found existing installation: jupyter_client 7.4.9
#     Uninstalling jupyter_client-7.4.9:
#       Successfully uninstalled jupyter_client-7.4.9
#   Attempting uninstall: ipython
#     Found existing installation: ipython 7.34.0
#     Uninstalling ipython-7.34.0:
#       Successfully uninstalled ipython-7.34.0
#   Attempting uninstall: grpcio-status
#     Found existing installation: grpcio-status 1.71.2
#     Uninstalling grpcio-status-1.71.2:
#       Successfully uninstalled grpcio-status-1.71.2
#   Attempting uninstall: google-api-core
#     Found existing installation: google-api-core 2.26.0
#     Uninstalling google-api-core-2.26.0:
#       Successfully uninstalled google-api-core-2.26.0
#   Attempting uninstall: aiohttp
#     Found existing installation: aiohttp 3.13.0
#     Uninstalling aiohttp-3.13.0:
#       Successfully uninstalled aiohttp-3.13.0
#   Attempting uninstall: openai
#     Found existing installation: openai 1.109.1
#     Uninstalling openai-1.109.1:
#       Successfully uninstalled openai-1.109.1
#   Attempting uninstall: langsmith
#     Found existing installation: langsmith 0.4.35
#     Uninstalling langsmith-0.4.35:
#       Successfully uninstalled langsmith-0.4.35
#   Attempting uninstall: ipykernel
#     Found existing installation: ipykernel 6.17.1
#     Uninstalling ipykernel-6.17.1:
#       Successfully uninstalled ipykernel-6.17.1
#   Attempting uninstall: google-genai
#     Found existing installation: google-genai 1.44.0
#     Uninstalling google-genai-1.44.0:
#       Successfully uninstalled google-genai-1.44.0
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 1.0.0
#     Uninstalling langchain-core-1.0.0:
#       Successfully uninstalled langchain-core-1.0.0
#   Attempting uninstall: google-ai-generativelanguage
#     Found existing installation: google-ai-generativelanguage 0.8.0
#     Uninstalling google-ai-generativelanguage-0.8.0:
#       Successfully uninstalled google-ai-generativelanguage-0.8.0
#   Attempting uninstall: langchain-google-genai
#     Found existing installation: langchain-google-genai 3.0.0
#     Uninstalling langchain-google-genai-3.0.0:
#       Successfully uninstalled langchain-google-genai-3.0.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires google-auth==2.38.0, but you have google-auth 2.41.1 which is incompatible.
# google-colab 1.0.0 requires ipykernel==6.17.1, but you have ipykernel 7.0.1 which is incompatible.
# google-colab 1.0.0 requires ipython==7.34.0, but you have ipython 9.6.0 which is incompatible.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.32.5 which is incompatible.
# google-colab 1.0.0 requires tornado==6.5.1, but you have tornado 6.5.2 which is incompatible.
# google-generativeai 0.8.5 requires google-ai-generativelanguage==0.6.15, but you have google-ai-generativelanguage 0.7.0 which is incompatible.
# notebook 6.5.7 requires jupyter-client<8,>=5.3.4, but you have jupyter-client 8.6.3 which is incompatible.
# opencv-python-headless 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 2.3.3 which is incompatible.
# bigframes 2.24.0 requires rich<14,>=12.4.4, but you have rich 14.1.0 which is incompatible.
# jupyter-kernel-gateway 2.5.2 requires jupyter-client<8.0,>=5.2.0, but you have jupyter-client 8.6.3 which is incompatible.
# cupy-cuda12x 13.3.0 requires numpy<2.3,>=1.22, but you have numpy 2.3.3 which is incompatible.
# opencv-contrib-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 2.3.3 which is incompatible.
# datasets 4.0.0 requires fsspec[http]<=2025.3.0,>=2023.1.0, but you have fsspec 2025.9.0 which is incompatible.
# tensorflow 2.19.0 requires numpy<2.2.0,>=1.26.0, but you have numpy 2.3.3 which is incompatible.
# tensorflow 2.19.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3, but you have protobuf 6.32.1 which is incompatible.
# gcsfs 2025.3.0 requires fsspec==2025.3.0, but you have fsspec 2025.9.0 which is incompatible.
# google-adk 1.16.0 requires google-genai<2.0.0,>=1.41.0, but you have google-genai 1.39.1 which is incompatible.
# google-adk 1.16.0 requires tenacity<9.0.0,>=8.0.0, but you have tenacity 9.1.2 which is incompatible.
# opencv-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 2.3.3 which is incompatible.
# moviepy 1.0.3 requires decorator<5.0,>=4.0.2, but you have decorator 5.2.1 which is incompatible.
# numba 0.60.0 requires numpy<2.1,>=1.22, but you have numpy 2.3.3 which is incompatible.
# Successfully installed PyPika-0.48.9 SQLAlchemy-2.0.43 aiohttp-3.12.15 aiosqlite-0.21.0 anthropic-0.69.0 asttokens-3.0.0 attrs-25.3.0 backoff-2.2.1 bcrypt-5.0.0 cachetools-6.2.0 certifi-2025.8.3 charset-normalizer-3.4.3 chromadb-1.1.0 colorama-0.4.6 coloredlogs-15.0.1 comm-0.2.3 dataclasses-json-0.6.7 debugpy-1.8.17 decorator-5.2.1 durationpy-0.10 executing-2.2.1 filelock-3.19.1 frozenlist-1.7.0 fsspec-2025.9.0 functions-0.7.0 google-ai-generativelanguage-0.7.0 google-api-core-2.25.1 google-auth-2.41.1 google-genai-1.39.1 grandalf-0.8 groq-0.32.0 grpcio-status-1.75.1 httptools-0.6.4 httpx-sse-0.4.1 humanfriendly-10.0 idna-3.10 ipykernel-7.0.1 ipython-9.6.0 ipython_pygments_lexers-1.1.1 jedi-0.19.2 jupyter_client-8.6.3 jupyter_core-5.9.1 kubernetes-34.1.0 langchain-anthropic-0.3.21 langchain-chroma-0.2.6 langchain-community-0.3.30 langchain-core-0.3.77 langchain-google-firestore-0.5.0 langchain-google-genai-2.1.12 langchain-groq-0.3.8 langchain-openai-0.3.34 langchain-tavily-0.2.12 langgraph-0.6.10 langgraph-checkpoint-2.1.1 langgraph-checkpoint-sqlite-2.0.11 langgraph-prebuilt-0.6.4 langgraph-sdk-0.2.9 langsmith-0.4.31 marshmallow-3.26.1 mmh3-5.2.0 multidict-6.6.4 mypy_extensions-1.1.0 numpy-2.3.3 onnxruntime-1.23.0 openai-2.0.1 opentelemetry-exporter-otlp-proto-grpc-1.37.0 ormsgpack-1.10.0 posthog-5.4.0 propcache-0.3.2 protobuf-6.32.1 psutil-7.1.0 pure_eval-0.2.3 pybase64-1.4.2 pydantic-2.11.9 pyreadline3-3.5.4 pyzmq-27.1.0 referencing-0.36.2 regex-2025.9.18 requests-2.32.5 rich-14.1.0 schemas-0.7.1 sqlite-vec-0.1.6 stack-data-0.6.3 sympy-1.14.0 tenacity-9.1.2 tiktoken-0.11.0 tornado-6.5.2 traitlets-5.14.3 typing-inspect-0.9.0 urllib3-2.3.0 uvloop-0.22.1 watchfiles-1.1.0 websocket-client-1.8.0 yarl-1.20.1

# %%
# !pip install -q langchain_google_genai

# %%
from dotenv import load_dotenv

load_dotenv()

from langchain.schema import Document
from langchain_google_genai import ChatGoogleGenerativeAI, GoogleGenerativeAIEmbeddings
from langchain_community.vectorstores import Chroma

embedding_function = GoogleGenerativeAIEmbeddings(model="gemini-embedding-001")

docs = [
    Document(
        page_content="Peak Performance Gym was founded in 2015 by former Olympic athlete Marcus Chen. With over 15 years of experience in professional athletics, Marcus established the gym to provide personalized fitness solutions for people of all levels. The gym spans 10,000 square feet and features state-of-the-art equipment.",
        metadata={"source": "about.txt"}
    ),
    Document(
        page_content="Peak Performance Gym is open Monday through Friday from 5:00 AM to 11:00 PM. On weekends, our hours are 7:00 AM to 9:00 PM. We remain closed on major national holidays. Members with Premium access can enter using their key cards 24/7, including holidays.",
        metadata={"source": "hours.txt"}
    ),
    Document(
        page_content="Our membership plans include: Basic (₹1,500/month) with access to gym floor and basic equipment; Standard (₹2,500/month) adds group classes and locker facilities; Premium (₹4,000/month) includes 24/7 access, personal training sessions, and spa facilities. We offer student and senior citizen discounts of 15% on all plans. Corporate partnerships are available for companies with 10+ employees joining.",
        metadata={"source": "membership.txt"}
    ),
    Document(
        page_content="Group fitness classes at Peak Performance Gym include Yoga (beginner, intermediate, advanced), HIIT, Zumba, Spin Cycling, CrossFit, and Pilates. Beginner classes are held every Monday and Wednesday at 6:00 PM. Intermediate and advanced classes are scheduled throughout the week. The full schedule is available on our mobile app or at the reception desk.",
        metadata={"source": "classes.txt"}
    ),
    Document(
        page_content="Personal trainers at Peak Performance Gym are all certified professionals with minimum 5 years of experience. Each new member receives a complimentary fitness assessment and one free session with a trainer. Our head trainer, Neha Kapoor, specializes in rehabilitation fitness and sports-specific training. Personal training sessions can be booked individually (₹800/session) or in packages of 10 (₹7,000) or 20 (₹13,000).",
        metadata={"source": "trainers.txt"}
    ),
    Document(
        page_content="Peak Performance Gym's facilities include a cardio zone with 30+ machines, strength training area, functional fitness space, dedicated yoga studio, spin class room, swimming pool (25m), sauna and steam rooms, juice bar, and locker rooms with shower facilities. Our equipment is replaced or upgraded every 3 years to ensure members have access to the latest fitness technology.",
        metadata={"source": "facilities.txt"}
    )
]

# %%
db = Chroma.from_documents(docs, embedding_function)
retriever = db.as_retriever(search_type="mmr", search_kwargs = {"k": 4})
retriever
# Out:
# VectorStoreRetriever(tags=['Chroma', 'GoogleGenerativeAIEmbeddings'], vectorstore=<langchain_community.vectorstores.chroma.Chroma object at 0x7ceed519d250>, search_type='mmr', search_kwargs={'k': 4})

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_openai import ChatOpenAI

llm = ChatGoogleGenerativeAI(model = "gemini-flash-lite-latest")

template = """Answer the question based on the following context and the Chathistory. Especially take the latest question into consideration:

Chathistory: {history}

Context: {context}

Question: {question}
"""
prompt = ChatPromptTemplate.from_template(template)

rag_chain = prompt | llm

# %%
from typing import TypedDict, List
from langchain_core.messages import BaseMessage, HumanMessage, AIMessage, SystemMessage
from langchain.schema import Document
from pydantic import BaseModel, Field
from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate
from langgraph.graph import StateGraph, END

class AgentState(TypedDict):
    messages: List[BaseMessage]
    documents: List[Document]
    on_topic: str
    rephrased_question: str
    proceed_to_generate: bool
    rephrase_count: int
    question: HumanMessage

class GradeQuestion(BaseModel):
    score: str = Field(
        description="Question is about the specified topics? If yes -> 'Yes' if not -> 'No'"
    )

def question_rewriter(state: AgentState):
    print(f"Entering question_rewriter with following state: {state}")

    # Reset state variables except for 'question' and 'messages'
    state["documents"] = []
    state["on_topic"] = ""
    state["rephrased_question"] = ""
    state["proceed_to_generate"] = False
    state["rephrase_count"] = 0

    if "messages" not in state or state["messages"] is None:
        state["messages"] = []

    if state["question"] not in state["messages"]:
        state["messages"].append(state["question"])

    if len(state["messages"]) > 1:
        conversation = state["messages"][:-1]
        current_question = state["question"].content
        messages = [
            SystemMessage(
                content="You are a helpful assistant that rephrases the user's question to be a standalone question optimized for retrieval."
            )
        ]
        # messages.extend(conversation)
        messages.append(HumanMessage(content=current_question))
        rephrase_prompt = ChatPromptTemplate.from_messages(messages)
        llm = ChatGoogleGenerativeAI(model = "gemini-flash-lite-latest")
        prompt = rephrase_prompt.format()
        response = llm.invoke(prompt)

        better_question = response.content.strip()
        messages.append(AIMessage(content=better_question))
        print(f"question_rewriter: Rephrased question: {better_question}")
        state["rephrased_question"] = better_question
    else:
        state["rephrased_question"] = state["question"].content
    return state

def question_classifier(state: AgentState):
    print("Entering question_classifier")
    system_message = SystemMessage(
        content=""" You are a classifier that determines whether a user's question is about one of the following topics

    1. Gym History & Founder
    2. Operating Hours
    3. Membership Plans
    4. Fitness Classes
    5. Personal Trainers
    6. Facilities & Equipment
    7. Anything else about Peak Performance Gym

    If the question IS about any of these topics, respond with 'Yes'. Otherwise, respond with 'No'.

    """
    )

    human_message = HumanMessage(
        content=f"User question: {state['rephrased_question']}"
    )
    grade_prompt = ChatPromptTemplate.from_messages([system_message, human_message])
    llm = ChatGoogleGenerativeAI(model = "gemini-flash-lite-latest")
    structured_llm = llm.with_structured_output(GradeQuestion)
    grader_llm = grade_prompt | structured_llm
    result = grader_llm.invoke({})
    state["on_topic"] = result.score.strip()
    print(f"question_classifier: on_topic = {state['on_topic']}")
    return state

def on_topic_router(state: AgentState):
    print("Entering on_topic_router")
    on_topic = state.get("on_topic", "").strip().lower()
    if on_topic == "yes":
        print("Routing to retrieve")
        return "retrieve"
    else:
        print("Routing to off_topic_response")
        return "off_topic_response"

def retrieve(state: AgentState):
    print("Entering retrieve")
    documents = retriever.invoke(state["rephrased_question"])
    print(f"retrieve: Retrieved {len(documents)} documents")
    state["documents"] = documents
    return state

class GradeDocument(BaseModel):
    score: str = Field(
        description="Document is relevant to the question? If yes -> 'Yes' if not -> 'No'"
    )

def retrieval_grader(state: AgentState):
    print("Entering retrieval_grader")
    system_message = SystemMessage(
        content="""You are a grader assessing the relevance of a retrieved document to a user question.
Only answer with 'Yes' or 'No'.

If the document contains information relevant to the user's question, respond with 'Yes'.
Otherwise, respond with 'No'."""
    )

    llm = ChatGoogleGenerativeAI(model = "gemini-flash-lite-latest")
    structured_llm = llm.with_structured_output(GradeDocument)

    relevant_docs = []
    for doc in state["documents"]:
        human_message = HumanMessage(
            content=f"User question: {state['rephrased_question']}\n\nRetrieved document:\n{doc.page_content}"
        )
        grade_prompt = ChatPromptTemplate.from_messages([system_message, human_message])
        grader_llm = grade_prompt | structured_llm
        result = grader_llm.invoke({})
        print(
            f"Grading document: {doc.page_content[:30]}... Result: {result.score.strip()}"
        )
        if result.score.strip().lower() == "yes":
            relevant_docs.append(doc)
    state["documents"] = relevant_docs
    state["proceed_to_generate"] = len(relevant_docs) > 0
    print(f"retrieval_grader: proceed_to_generate = {state['proceed_to_generate']}")
    return state

def proceed_router(state: AgentState):
    print("Entering proceed_router")
    rephrase_count = state.get("rephrase_count", 0)
    if state.get("proceed_to_generate", False):
        print("Routing to generate_answer")
        return "generate_answer"
    elif rephrase_count >= 2:
        print("Maximum rephrase attempts reached. Cannot find relevant documents.")
        return "cannot_answer"
    else:
        print("Routing to refine_question")
        return "refine_question"

def refine_question(state: AgentState):
    print("Entering refine_question")
    rephrase_count = state.get("rephrase_count", 0)
    if rephrase_count >= 2:
        print("Maximum rephrase attempts reached")
        return state
    question_to_refine = state["rephrased_question"]
    system_message = SystemMessage(
        content="""You are a helpful assistant that slightly refines the user's question to improve retrieval results.
Provide a slightly adjusted version of the question."""
    )
    human_message = HumanMessage(
        content=f"Original question: {question_to_refine}\n\nProvide a slightly refined question."
    )
    refine_prompt = ChatPromptTemplate.from_messages([system_message, human_message])
    llm = ChatGoogleGenerativeAI(model = "gemini-flash-lite-latest")
    prompt = refine_prompt.format()
    response = llm.invoke(prompt)
    refined_question = response.content.strip()
    print(f"refine_question: Refined question: {refined_question}")
    state["rephrased_question"] = refined_question
    state["rephrase_count"] = rephrase_count + 1
    return state

def generate_answer(state: AgentState):
    print("Entering generate_answer")
    if "messages" not in state or state["messages"] is None:
        raise ValueError("State must include 'messages' before generating an answer.")

    history = state["messages"]
    documents = state["documents"]
    rephrased_question = state["rephrased_question"]

    response = rag_chain.invoke(
        {"history": history, "context": documents, "question": rephrased_question}
    )

    generation = response.content.strip()

    state["messages"].append(AIMessage(content=generation))
    print(f"generate_answer: Generated response: {generation}")
    return state

def cannot_answer(state: AgentState):
    print("Entering cannot_answer")
    if "messages" not in state or state["messages"] is None:
        state["messages"] = []
    state["messages"].append(
        AIMessage(
            content="I'm sorry, but I cannot find the information you're looking for."
        )
    )
    return state


def off_topic_response(state: AgentState):
    print("Entering off_topic_response")
    if "messages" not in state or state["messages"] is None:
        state["messages"] = []
    state["messages"].append(AIMessage(content="I'm sorry! I cannot answer this question!"))
    return state

# %%
from langgraph.checkpoint.memory import MemorySaver
checkpointer = MemorySaver()

# %%
# Workflow
workflow = StateGraph(AgentState)
workflow.add_node("question_rewriter", question_rewriter)
workflow.add_node("question_classifier", question_classifier)
workflow.add_node("off_topic_response", off_topic_response)
workflow.add_node("retrieve", retrieve)
workflow.add_node("retrieval_grader", retrieval_grader)
workflow.add_node("generate_answer", generate_answer)
workflow.add_node("refine_question", refine_question)
workflow.add_node("cannot_answer", cannot_answer)

workflow.add_edge("question_rewriter", "question_classifier")
workflow.add_conditional_edges(
    "question_classifier",
    on_topic_router,
    {
        "retrieve": "retrieve",
        "off_topic_response": "off_topic_response",
    },
)
workflow.add_edge("retrieve", "retrieval_grader")
workflow.add_conditional_edges(
    "retrieval_grader",
    proceed_router,
    {
        "generate_answer": "generate_answer",
        "refine_question": "refine_question",
        "cannot_answer": "cannot_answer",
    },
)
workflow.add_edge("refine_question", "retrieve")
workflow.add_edge("generate_answer", END)
workflow.add_edge("cannot_answer", END)
workflow.add_edge("off_topic_response", END)
workflow.set_entry_point("question_rewriter")
graph = workflow.compile(checkpointer=checkpointer)

# %%
from IPython.display import Image, display
from langchain_core.runnables.graph import MermaidDrawMethod

display(
    Image(
        graph.get_graph().draw_mermaid_png(
            draw_method=MermaidDrawMethod.API,
        )
    )
)

# %%
input_data = {"question": HumanMessage(content="What does the company Apple do?")}
graph.invoke(input=input_data, config={"configurable": {"thread_id": 1}})
# Out:
# Entering question_rewriter with following state: {'question': HumanMessage(content='What does the company Apple do?', additional_kwargs={}, response_metadata={})}
# Entering question_classifier
# question_classifier: on_topic = No
# Entering on_topic_router
# Routing to off_topic_response
# Entering off_topic_response
# {'messages': [HumanMessage(content='What does the company Apple do?', additional_kwargs={}, response_metadata={}),
#   AIMessage(content="I'm sorry! I cannot answer this question!", additional_kwargs={}, response_metadata={})],
#  'documents': [],
#  'on_topic': 'No',
#  'rephrased_question': 'What does the company Apple do?',
#  'proceed_to_generate': False,
#  'rephrase_count': 0,
#  'question': HumanMessage(content='What does the company Apple do?', additional_kwargs={}, response_metadata={})}

# %%
input_data = {
    "question": HumanMessage(
        content="What is the cancelation policy for Peak Performance Gym memberships?"
    )
}
graph.invoke(input=input_data, config={"configurable": {"thread_id": 2}})
# Out:
# Entering question_rewriter with following state: {'question': HumanMessage(content='What is the cancelation policy for Peak Performance Gym memberships?', additional_kwargs={}, response_metadata={})}
# Entering question_classifier
# question_classifier: on_topic = Membership Plans
# Entering on_topic_router
# Routing to off_topic_response
# Entering off_topic_response
# {'messages': [HumanMessage(content='What is the cancelation policy for Peak Performance Gym memberships?', additional_kwargs={}, response_metadata={}),
#   AIMessage(content="I'm sorry! I cannot answer this question!", additional_kwargs={}, response_metadata={})],
#  'documents': [],
#  'on_topic': 'Membership Plans',
#  'rephrased_question': 'What is the cancelation policy for Peak Performance Gym memberships?',
#  'proceed_to_generate': False,
#  'rephrase_count': 0,
#  'question': HumanMessage(content='What is the cancelation policy for Peak Performance Gym memberships?', additional_kwargs={}, response_metadata={})}

# %%
input_data = {
    "question": HumanMessage(content="Who founded Peak Performance Gym?")
}
graph.invoke(input=input_data, config={"configurable": {"thread_id": 3}})
# Out:
# Entering question_rewriter with following state: {'question': HumanMessage(content='Who founded Peak Performance Gym?', additional_kwargs={}, response_metadata={})}
# Entering question_classifier
# question_classifier: on_topic = Yes
# Entering on_topic_router
# Routing to retrieve
# Entering retrieve
# retrieve: Retrieved 4 documents
# Entering retrieval_grader
# Grading document: Peak Performance Gym was found... Result: Yes
# Grading document: Peak Performance Gym is open M... Result: No
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-4243973595.py in <cell line: 0>()
#       2     "question": HumanMessage(content="Who founded Peak Performance Gym?")
#       3 }
# ----> 4 graph.invoke(input=input_data, config={"configurable": {"thread_id": 3}})
#
# /usr/local/lib/python3.12/dist-packages/langgraph/pregel/main.py in invoke(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, **kwargs)
#    3083         interrupts: list[Interrupt] = []
#    3084
# -> 3085         for chunk in self.stream(
#    3086             input,
#    3087             config,
#
# /usr/local/lib/python3.12/dist-packages/langgraph/pregel/main.py in stream(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, subgraphs, debug, **kwargs)
#    2672                     for task in loop.match_cached_writes():
#    2673                         loop.output_writes(task.id, task.writes, cached=True)
# -> 2674                     for _ in runner.tick(
#    2675                         [t for t in loop.tasks.values() if not t.writes],
#    2676                         timeout=self.step_timeout,
#
# /usr/local/lib/python3.12/dist-packages/langgraph/pregel/_runner.py in tick(self, tasks, reraise, timeout, retry_policy, get_waiter, schedule_task)
#     160             t = tasks[0]
#     161             try:
# --> 162                 run_with_retry(
#     163                     t,
#     164                     retry_policy,
#
# /usr/local/lib/python3.12/dist-packages/langgraph/pregel/_retry.py in run_with_retry(task, retry_policy, configurable)
#      40             task.writes.clear()
#      41             # run the task
# ---> 42             return task.proc.invoke(task.input, config)
#      43         except ParentCommand as exc:
#      44             ns: str = config[CONF][CONFIG_KEY_CHECKPOINT_NS]
#
# /usr/local/lib/python3.12/dist-packages/langgraph/_internal/_runnable.py in invoke(self, input, config, **kwargs)
#     655                     # run in context
#     656                     with set_config_context(config, run) as context:
# --> 657                         input = context.run(step.invoke, input, config, **kwargs)
#     658                 else:
#     659                     input = step.invoke(input, config)
#
# /usr/local/lib/python3.12/dist-packages/langgraph/_internal/_runnable.py in invoke(self, input, config, **kwargs)
#     399                 run_manager.on_chain_end(ret)
#     400         else:
# --> 401             ret = self.func(*args, **kwargs)
#     402         if self.recurse and isinstance(ret, Runnable):
#     403             return ret.invoke(input, config)
#
# /tmp/ipython-input-3340730319.py in retrieval_grader(state)
#     134         result = grader_llm.invoke({})
#     135         print(
# --> 136             f"Grading document: {doc.page_content[:30]}... Result: {result.score.strip()}"
#     137         )
#     138         if result.score.strip().lower() == "yes":
#
# AttributeError: 'NoneType' object has no attribute 'score'

# %% [markdown]
# # Becaue of pydantic parsing it failed

# %%
input_data = {"question": HumanMessage(content="When did he start it?")}
graph.invoke(input=input_data, config={"configurable": {"thread_id": 3}})
# Out:
# Entering question_rewriter with following state: {'messages': [HumanMessage(content='Who founded Peak Performance Gym?', additional_kwargs={}, response_metadata={}), HumanMessage(content='When did he start it?', additional_kwargs={}, response_metadata={})], 'documents': [], 'on_topic': '', 'rephrased_question': 'What is the starting date for the event or action referred to by "it"?', 'proceed_to_generate': False, 'rephrase_count': 0, 'question': HumanMessage(content='When did he start it?', additional_kwargs={}, response_metadata={})}
# question_rewriter: Rephrased question: When did the individual referred to as "he" begin the activity, project, or endeavor in question?
# Entering question_classifier
# question_classifier: on_topic = Yes
# Entering on_topic_router
# Routing to retrieve
# Entering retrieve
# retrieve: Retrieved 4 documents
# Entering retrieval_grader
# Grading document: Peak Performance Gym was found... Result: Yes
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-574580217.py in <cell line: 0>()
#       1 input_data = {"question": HumanMessage(content="When did he start it?")}
# ----> 2 graph.invoke(input=input_data, config={"configurable": {"thread_id": 3}})
#
# /usr/local/lib/python3.12/dist-packages/langgraph/pregel/main.py in invoke(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, **kwargs)
#    3083         interrupts: list[Interrupt] = []
#    3084
# -> 3085         for chunk in self.stream(
#    3086             input,
#    3087             config,
#
# /usr/local/lib/python3.12/dist-packages/langgraph/pregel/main.py in stream(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, subgraphs, debug, **kwargs)
#    2672                     for task in loop.match_cached_writes():
#    2673                         loop.output_writes(task.id, task.writes, cached=True)
# -> 2674                     for _ in runner.tick(
#    2675                         [t for t in loop.tasks.values() if not t.writes],
#    2676                         timeout=self.step_timeout,
#
# /usr/local/lib/python3.12/dist-packages/langgraph/pregel/_runner.py in tick(self, tasks, reraise, timeout, retry_policy, get_waiter, schedule_task)
#     160             t = tasks[0]
#     161             try:
# --> 162                 run_with_retry(
#     163                     t,
#     164                     retry_policy,
#
# /usr/local/lib/python3.12/dist-packages/langgraph/pregel/_retry.py in run_with_retry(task, retry_policy, configurable)
#      40             task.writes.clear()
#      41             # run the task
# ---> 42             return task.proc.invoke(task.input, config)
#      43         except ParentCommand as exc:
#      44             ns: str = config[CONF][CONFIG_KEY_CHECKPOINT_NS]
#
# /usr/local/lib/python3.12/dist-packages/langgraph/_internal/_runnable.py in invoke(self, input, config, **kwargs)
#     655                     # run in context
#     656                     with set_config_context(config, run) as context:
# --> 657                         input = context.run(step.invoke, input, config, **kwargs)
#     658                 else:
#     659                     input = step.invoke(input, config)
#
# /usr/local/lib/python3.12/dist-packages/langgraph/_internal/_runnable.py in invoke(self, input, config, **kwargs)
#     399                 run_manager.on_chain_end(ret)
#     400         else:
# --> 401             ret = self.func(*args, **kwargs)
#     402         if self.recurse and isinstance(ret, Runnable):
#     403             return ret.invoke(input, config)
#
# /tmp/ipython-input-3340730319.py in retrieval_grader(state)
#     134         result = grader_llm.invoke({})
#     135         print(
# --> 136             f"Grading document: {doc.page_content[:30]}... Result: {result.score.strip()}"
#     137         )
#     138         if result.score.strip().lower() == "yes":
#
# AttributeError: 'NoneType' object has no attribute 'score'
